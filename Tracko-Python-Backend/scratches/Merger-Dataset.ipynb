# %%
import pandas as pd
import numpy as np

# %%
adf = pd.read_csv("sms-data-aman.csv")

# %%
edf = pd.read_excel("sms-data.xls")

# %%
body = adf['body']
body2 = edf['Body']
cls = adf['class']
cls2 = edf['class']
len(body2)
len(body)
body.append(body2)
len(body)
# Out:
# 2609

# %%
mbody = []
mbody.extend(body)
mbody.extend(body2)
n = len(mbody)
mcls = []
mcls.extend(cls)
mcls.extend(cls2)
n = len(mcls)

# %%
data = {'body':mbody,'class':mcls}
df = pd.DataFrame(data)

# %%
df.to_csv("merge-data.csv",index=False)
